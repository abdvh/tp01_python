# %% [markdown]
# LES NOMBRES SUPERPREMIERS

# %%
premier = True
a = int(input("entrer: "))

for i in range (2,a):
  if(a % i == 0):
    premier = False
    break
b = a // 10
super_premier  = True
for i  in range(2, b):
    if (b% i == 0):
        super_premier = False
        break
    

if super_premier:
  print("Ce nombre est super premier")

else:
  print("Ce nombre n'est pas un super premier")
# Out:
# Ce nombre est super premier

# %% [markdown]
# LES TYPES DES NOMBRES

# %%
N = int(input("entrer un nombre"))
M=N
C= M
inverse = 0
while N!=0:
    inverse= (inverse * 10)+(N%10)
    N=N//10
if (M * (M%10))!=inverse and M != inverse :
    print(C,"est non symetrique et  non propre")
elif (M * (M%10))==inverse and M == inverse :
    print(C,"est  symetrique et   propre")
elif M == inverse:
    print(C,"est symetrique")
elif (M * (M%10))==inverse:
    print(C, "est propre")
# Out:
# 1234 est non symetrique et  non propre

# %% [markdown]
# LES NOMBRES CERCULAIRES

# %%
import math as mt
 
def premier(n):
    if n == 2:
        return True
    etat = True
    for i in range(2, int(mt.sqrt(n))+2):
        if n % i == 0:
            etat = False
            break
    return etat
 
def circulaire(p, q):
    for i in range(p, q+1):
        if premier(i) == True:
            etat = True
            ch = str(i)
            k = 0
            while k < len(ch) and etat == True:
                ch = ch[-1]+ch[:len(ch)-1]
                if premier(int(ch)) == False:
                    etat = False
                    break
                k += 1
            if etat == True:
                print('nombre : ', i)
 
print("entrer l'intervalle [bi..bs] dont les nombres circulaires seront affichés")
bi=int(input("entrer BI "))
bs=int(input("entrer BS "))
circulaire(bi, bs)
# Out:
# entrer l'intervalle [bi..bs] dont les nombres circulaires seront affichés
# nombre :  113
# nombre :  131
# nombre :  197
# nombre :  199
# nombre :  311
# nombre :  337
# nombre :  373
